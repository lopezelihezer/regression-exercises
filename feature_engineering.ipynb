# %% [markdown]
# # Feature Engineering Exercises

# %%
import pandas as pd
import numpy as np
import pydataset

from sklearn.feature_selection import SelectKBest, f_regression, RFE
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

df = pydataset.data('tips')

# %% [markdown]
# 1. Load the tips dataset

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       16.99  1.01  Female     No  Sun  Dinner     2
# 2       10.34  1.66    Male     No  Sun  Dinner     3
# 3       21.01  3.50    Male     No  Sun  Dinner     3
# 4       23.68  3.31    Male     No  Sun  Dinner     2
# 5       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# a. Create the column named tip_percentage. This should be the tip amount divided by the total bill.

# %%
df['tip_percentage'] = df.tip/df.total_bill
df.tip_percentage
# Out:
# 1      0.059447
# 2      0.160542
# 3      0.166587
# 4      0.139780
# 5      0.146808
#          ...
# 240    0.203927
# 241    0.073584
# 242    0.088222
# 243    0.098204
# 244    0.159744
# Name: tip_percentage, Length: 244, dtype: float64

# %% [markdown]
# b. Create the column named price_per_person. This should be the total bill divided by the party size.

# %%
df['party_size'] = df['size']
df['price_per_person'] = df.total_bill/df.party_size
df.price_per_person
# Out:
# 1       8.495000
# 2       3.446667
# 3       7.003333
# 4      11.840000
# 5       6.147500
#          ...
# 240     9.676667
# 241    13.590000
# 242    11.335000
# 243     8.910000
# 244     9.390000
# Name: price_per_person, Length: 244, dtype: float64

# %% [markdown]
# c. Before using any of the methods discussed in the lesson, which features do you think would be most important for predicting the tip amount? The tip percentage?

# %% [markdown]
# hypothesis = total_bill is the most important in predicting the tip amount

# %% [markdown]
# d. Use select k best and recursive feature elimination to select the top 2 features for predicting tip amount. What are they?

# %%
df = df.drop(columns=['size'])
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  tip_percentage  party_size  \
# 1       16.99  1.01  Female     No  Sun  Dinner        0.059447           2
# 2       10.34  1.66    Male     No  Sun  Dinner        0.160542           3
# 3       21.01  3.50    Male     No  Sun  Dinner        0.166587           3
# 4       23.68  3.31    Male     No  Sun  Dinner        0.139780           2
# 5       24.59  3.61  Female     No  Sun  Dinner        0.146808           4
#
#    price_per_person
# 1          8.495000
# 2          3.446667
# 3          7.003333
# 4         11.840000
# 5          6.147500

# %%
df.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
dummy_df = pd.get_dummies(df[['sex', 'day', 'time', 'smoker']])
dummy_df
# Out:
#      sex_Female  sex_Male  day_Fri  day_Sat  day_Sun  day_Thur  time_Dinner  \
# 1             1         0        0        0        1         0            1
# 2             0         1        0        0        1         0            1
# 3             0         1        0        0        1         0            1
# 4             0         1        0        0        1         0            1
# 5             1         0        0        0        1         0            1
# ..          ...       ...      ...      ...      ...       ...          ...
# 240           0         1        0        1        0         0            1
# 241           1         0        0        1        0         0            1
# 242           0         1        0        1        0         0            1
# 243           0         1        0        1        0         0            1
# 244           1         0        0        0        0         1            1
#
#      time_Lunch  smoker_No  smoker_Yes
# 1             0          1           0
# 2             0          1           0
# 3             0          1           0
# 4             0          1           0
# 5             0          1           0
# ..          ...        ...         ...
# 240           0          1           0
# 241           0          0           1
# 242           0          0           1
# 243           0          1           0
# 244           0          1           0
#
# [244 rows x 10 columns]

# %%
df = pd.concat([df, dummy_df], axis=1)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  tip_percentage  party_size  \
# 1       16.99  1.01  Female     No  Sun  Dinner        0.059447           2
# 2       10.34  1.66    Male     No  Sun  Dinner        0.160542           3
# 3       21.01  3.50    Male     No  Sun  Dinner        0.166587           3
# 4       23.68  3.31    Male     No  Sun  Dinner        0.139780           2
# 5       24.59  3.61  Female     No  Sun  Dinner        0.146808           4
#
#    price_per_person  sex_Female  sex_Male  day_Fri  day_Sat  day_Sun  \
# 1          8.495000           1         0        0        0        1
# 2          3.446667           0         1        0        0        1
# 3          7.003333           0         1        0        0        1
# 4         11.840000           0         1        0        0        1
# 5          6.147500           1         0        0        0        1
#
#    day_Thur  time_Dinner  time_Lunch  smoker_No  smoker_Yes
# 1         0            1           0          1           0
# 2         0            1           0          1           0
# 3         0            1           0          1           0
# 4         0            1           0          1           0
# 5         0            1           0          1           0

# %%
df = df.drop(columns=['sex', 'smoker', 'day', 'time', 'sex_Female', 'time_Lunch', 'smoker_No'])

# %%
df.head()
# Out:
#    total_bill   tip  tip_percentage  party_size  price_per_person  sex_Male  \
# 1       16.99  1.01        0.059447           2          8.495000         0
# 2       10.34  1.66        0.160542           3          3.446667         1
# 3       21.01  3.50        0.166587           3          7.003333         1
# 4       23.68  3.31        0.139780           2         11.840000         1
# 5       24.59  3.61        0.146808           4          6.147500         0
#
#    day_Fri  day_Sat  day_Sun  day_Thur  time_Dinner  smoker_Yes
# 1        0        0        1         0            1           0
# 2        0        0        1         0            1           0
# 3        0        0        1         0            1           0
# 4        0        0        1         0            1           0
# 5        0        0        1         0            1           0

# %%
X = df.drop(columns='tip')
y = df.tip

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=123)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
kbest = SelectKBest(f_regression, k=3)
kbest.fit(X_train_scaled, y_train)

X_train.columns[kbest.get_support()]
# Out:
# Index(['total_bill', 'tip_percentage', 'party_size'], dtype='object')

# %%
pd.Series(X_train.columns, index=kbest.scores_).sort_index(0)
# Out:
# 0.000154            smoker_Yes
# 0.000155               day_Sat
# 0.691348              day_Thur
# 1.313965              sex_Male
# 1.669530           time_Dinner
# 1.826904               day_Fri
# 2.352264               day_Sun
# 26.729545     price_per_person
# 29.605028       tip_percentage
# 65.274770           party_size
# 172.913650          total_bill
# dtype: object

# %%
tips = pydataset.data('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       16.99  1.01  Female     No  Sun  Dinner     2
# 2       10.34  1.66    Male     No  Sun  Dinner     3
# 3       21.01  3.50    Male     No  Sun  Dinner     3
# 4       23.68  3.31    Male     No  Sun  Dinner     2
# 5       24.59  3.61  Female     No  Sun  Dinner     4

# %%
for column in tips.columns:
    if tips[column].dtype == np.number:
        continue
    tips[column] = LabelEncoder().fit_transform(tips[column])
# Out:
# <ipython-input-15-9ac351105231>:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if tips[column].dtype == np.number:

# %%
tips.head()
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 1       16.99  1.01    0       0    2     0     1
# 2       10.34  1.66    1       0    2     0     2
# 3       21.01  3.50    1       0    2     0     2
# 4       23.68  3.31    1       0    2     0     1
# 5       24.59  3.61    0       0    2     0     3

# %%
tips['tip_percentage'] = round((tips.tip/tips.total_bill), 2)
tips['party_size'] = tips['size']
tips['price_per_person'] = round((tips.total_bill/tips.party_size),2)
tips = tips.drop(columns=['size'])
tips.head()
# Out:
#    total_bill   tip  sex  smoker  day  time  tip_percentage  party_size  \
# 1       16.99  1.01    0       0    2     0            0.06           1
# 2       10.34  1.66    1       0    2     0            0.16           2
# 3       21.01  3.50    1       0    2     0            0.17           2
# 4       23.68  3.31    1       0    2     0            0.14           1
# 5       24.59  3.61    0       0    2     0            0.15           3
#
#    price_per_person
# 1             16.99
# 2              5.17
# 3             10.50
# 4             23.68
# 5              8.20

# %%
X = tips.drop(columns='tip')
y = tips.tip

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=123)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

kbest = SelectKBest(f_regression, k=3)
kbest.fit(X_train_scaled, y_train)

X_train.columns[kbest.get_support()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-899933712606> in <module>
#       4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=123)
#       5 scaler = StandardScaler()
# ----> 6 X_train_scaled = scaler.fit_transform(X_train)
#       7 X_test_scaled = scaler.transform(X_test)
#       8
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     767                                 estimator=self, dtype=FLOAT_DTYPES,
#     768                                 force_all_finite='allow-nan', reset=first_call)
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     661
#     662         if force_all_finite:
# --> 663             _assert_all_finite(array,
#     664                                allow_nan=force_all_finite == 'allow-nan')
#     665
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains infinity or a value too large for dtype('float64').

# %%
pd.Series(X_train.columns, index=kbest.scores_).sort_index(0)
